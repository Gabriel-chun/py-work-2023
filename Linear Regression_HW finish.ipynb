# %% [markdown]
# ## 基礎題 - 算出斜率w與截距b
#
# y = wx + b
#
# 記得計算前X須符合資料格式
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#將模型工具指派給一變數做使用
#注意轉換x得格式1D->2D
#將x,y資料導入LinearRegression演算法做訓練
#列印出訓練完成之函數的斜率與截距

# %%
from sklearn.linear_model import LinearRegression
#轉換維度
x = x.reshape(-1, 1)
#資料都導入 進行訓練
reg = LinearRegression().fit(x, y)
print('Coefficients: ', reg.coef_[0])
print('interception: ', reg.intercept_)
# Out:
# Coefficients:  1.617018521261157
# interception:  0.2731296894942137

# %% [markdown]
# ## 進階題 - 切割資料集分別做訓練與預測(訓練資料80%、測試資料20%)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
        1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
        2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
        3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
        4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
        5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
        6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
        7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
        8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
        9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])
y = np.array([ 0.85848224, -0.10657947,  1.42771901,  0.53554778,  1.20216826,
        1.81330509,  1.88362644,  2.23557653,  2.7384889 ,  3.41174583,
        4.08573636,  3.82529502,  4.39723111,  4.8852381 ,  4.70092778,
        4.66993962,  6.05133235,  5.44529881,  7.22571332,  6.79423911,
        7.05424438,  7.00413058,  7.98149596,  7.00044008,  7.95903855,
        9.96125238,  9.06040794,  9.56018295,  9.30035956,  9.26517614,
        9.56401824, 10.07659844, 11.56755942, 11.38956185, 11.83586027,
       12.45642786, 11.58403954, 11.60186428, 13.88486667, 13.35550112,
       13.93938726, 13.31678277, 13.69551472, 14.76548676, 14.81731598,
       14.9659187 , 15.19213921, 15.28195017, 15.97997265, 16.41258817])

# %%
#匯入在sklearn.linear_model套件裡面的LinearRegression模型
#匯入在sklearn.model_selection套件裡面的train_test_split模組
#切割數據集(訓練資料80%、測試資料20%，設定random_state=20)
#畫出訓練資料集的matplotlib圖形m

# %%
'''''''''''
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
'''''''''
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x.reshape(-1, 1), y, test_size=0.2, random_state=20)
lr = LinearRegression()
lr.fit(X_train, y_train)
plt.scatter(X_train, y_train)
plt.plot(X_train, lr.predict(X_train), color='red')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## 用訓練資料來 fit 函數
# 1. 只用訓練資料集的資料進行linear regression演算法<br>
# 2. 並計算出訓練階段的MSE
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_train.PNG)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# 切割數據集(訓練資料80%、測試資料20%，設定random_state=20)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)

# 將X_train轉成2D array以符合fit函數的需求--維度轉換
X_train = X_train.reshape(-1, 1)

# 建立Linear Regression模型並fit訓練資料
reg = LinearRegression()
reg.fit(X_train, y_train)

# 預測訓練資料集的y值
model=y_pred_train = reg.predict(X_train)

# 計算訓練階段的MSE
train_mse = mean_squared_error(y_train, y_pred_train)
print("訓練階段的MSE:", train_mse)

# 畫出目標點(藍色)與預測點(紅色)的對應圖
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, y_pred_train, color='red')
plt.show()


'''''''''
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
regr_lin.fit(X,y)
'''''''''
# Out:
# 訓練階段的MSE: 0.2284495300761316
# '\nx = np.linspace(0, 5, 50)\ny = 1.2*x + 0.8 + 0.6*np.random.randn(50)\nx_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)\nprint(x_train)\nregr_lin.fit(X,y)\n'

# %% [markdown]
# ## 將訓練出來的函數預測測試集的X值
# 1. 使用剛剛訓練出來的模型進行測試資料集的資料預測*注意reshape<br>
# 使用X = 2.44897959，預測出來數值應該為 4.3025375<br>
# 所有測試集資料
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
from sklearn.linear_model import LinearRegression

# 創建線性回歸模型
model = LinearRegression()

# 將訓練資料 fit 到模型上
model.fit(X_train, y_train)

# 驗證特定值
X = np.array([2.44897959]).reshape(-1, 1)
y_pred = model.predict(X)
print(f"X = {X[0][0]:.8f}, 預測值 = {y_pred[0]:.8f}")

# 將測試集的 X 值預測出來
X_test = X_test.reshape(-1, 1)
y_pred = model.predict(X_test)

# 印出預測結果
for i in range(len(X_test)):
    print(f"X = {X_test[i][0]:.8f}, 預測值 = {y_pred[i]:.8f}")


#X值二維陣列進行預測--列印出以後進行整理預測數值資料
#在過程中有出現model的報錯將model物件修改成scikit-learn的linear regression物件即可完成
# Out:
# X = 2.44897959, 預測值 = 4.30253750
# X = 2.44897959, 預測值 = 4.30253750
# X = 2.85714286, 預測值 = 4.95828946
# X = 0.81632653, 預測值 = 1.67952971
# X = 1.63265306, 預測值 = 2.99103361
# X = 9.18367347, 預測值 = 15.12244466
# X = 0.20408163, 預測值 = 0.69590179
# X = 5.10204082, 預測值 = 8.56492518
# X = 4.89795918, 預測值 = 8.23704919
# X = 9.59183673, 預測值 = 15.77819660
# X = 4.69387755, 預測值 = 7.90917322

# %%
''''''''''
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
'''''''''''
# Out:
# "'\nY=regr_lin.predict(X)\nplt.scatter(x,y)\nplt.plot(x,Y , color='r')\nmse = np.sum((Y-y)**2) / len(y)\nprint(mse)\n"

# %%
# 計算測試階段的MSE
from sklearn.metrics import mean_squared_error

y_test_pred = model.predict(X_test)
mse_test = mean_squared_error(y_test, y_test_pred)
print(f"測試階段的MSE: {mse_test:.8f}")
# Out:
# 測試階段的MSE: 0.41344073

# %% [markdown]
# 2. 並計算出測試階段的MSE

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train, y_train, color='blue', label='Training Data')
plt.scatter(X_test, y_test, color='red', label='Testing Data')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# 3. 畫出目標點(藍色)與預測點(紅色)的對應圖
# ![](images/LR_test.PNG)

# %%
#plt.scatter(x_train, y_train)
#plt.plot(x_train, Y_train, 'r')
''''''''''
title='f(x)=1.2x+0.8'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()#使用的模型跟差距大概在多少 模型的好壞大概的誤差在哪裡 線性回歸模型的測試
'''''''''''''''
